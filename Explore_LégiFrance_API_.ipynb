# %% [markdown]
# # 1 - API connect

# %%
import sys
print(sys.version)
# Out:
# 3.10.12 (main, Sep 11 2024, 15:47:36) [GCC 11.4.0]

# %%
pip install python-dotenv
# Out:
# Collecting python-dotenv
#   Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Installing collected packages: python-dotenv
# Successfully installed python-dotenv-1.0.1

# %%
import os
from dotenv import load_dotenv
import requests
from requests_oauthlib import OAuth2Session
import json

# %%
#option 2:
import requests

# idenifiants  API
client_id = '2bd5c3ac-5128-4527-b74f-5d3e90e47efb'
client_secret = 'de5cf33d-fbee-4368-8fe9-e803490fe096'

# URL pour obtenir le jeton
token_url = 'https://sandbox-oauth.piste.gouv.fr/api/oauth/token'

# inject cred for token request
token_data = {
    'grant_type': 'client_credentials',
    'client_id': client_id,
    'client_secret': client_secret,
    'scope': 'openid'
}

# run the request
response = requests.post(token_url, data=token_data)
response.raise_for_status()  # vérif  erreurs

# récup  jeton
token_info = response.json()
access_token = token_info['access_token']

# %%
print(access_token)
# Out:
# yIGkWxQIXiWEIOI2qK2qgvcCKXXzOzKZo7PLAmvKAY7R8cYJB38vo7

# %% [markdown]
# # 2 - API Call
#
# Environ 70 requetes, en 6 "types"/"familles" de requêtes:
#
# 1 - Consult Controller
#
# 2 - List Controller
#
# 3 - Suggest Controller
#
# 4 - Misc Controller
#
# 5 - Search Controller
#
# 6 - Chrono Controller : pour accéder à l'historique et à l'évolution chronologique des textes.
#
# Q : permet de retracer et comprendre la version d'un texte en vigueur à une date donnée ou de suivre ses modifications ?

# %% [markdown]
# ## 2.0 - Ping/Pong Test

# %%
# Call 1 : Ping/Pong
headers_1=  {
		'accept': 'text/plain',
		'Authorization': 'Bearer ' + access_token
	}

output = requests.get("https://sandbox-api.piste.gouv.fr/dila/legifrance/lf-engine-app/consult/ping",
                       headers = headers_1).text

display(output)
# Out:
# 'pong'

# %% [markdown]
# ## 2.1 - Consult Controller

# %% [markdown]
# ### 2.1.1 - Contenu Article - Eli
#
#
# Eli - Identifiant Européen de la Législation:
#
# - Permet d'identifier de façon unique les documents législatifs et réglementaires au sein de la base de données de Légifrance.
#
# - Déclinaison :
#
# /eli : Préfixe indiquant qu'il s'agit d'un identifiant ELI.
#
# /decret : Type de texte (ici un décret) peut aussi être un arrêté, une loi, ou d'autres types d'actes normatifs...
#
# /2021/7/13 : Date de publication ou adoption (13 juillet 2021 dans cet exemple).
#
# /PRMD2117108D : Numéro unique du décret
#
# /jo : Indication que le document a été publié dans le Journal Officiel.
#
# /article_1 : Référence à un article spécifique dans le document (ici l'article 1).
#
# - Sources:
#
# https://eur-lex.europa.eu/content/help/eurlex-content/eli.html?locale=fr#:~:text=L%27identifiant%20europ%C3%A9en%20de%20la,r%C3%A9utiliser%20par%2Ddel%C3%A0%20les%20fronti%C3%A8res.
#
#
# https://eur-lex.europa.eu/eli-register/about.html?locale=fr

# %%
# Call 2: Contenu article
headers_2 = {
    "accept": "application/json",
    "Content-Type": "application/json",
    'Authorization': 'Bearer ' + access_token}

data = {
    "idEliOrAlias": "/eli/decret/2021/7/13/PRMD2117108D/jo/article_1"
}

url= "https://sandbox-api.piste.gouv.fr/dila/legifrance/lf-engine-app/consult/getArticleWithIdEliOrAlias"
response = requests.post(url,
                         headers=headers_2,
                         json=data) # dictionnaire data converti en JSON
                                    #inject request

# %%
response_json = response.json()
display(response_json) #datetype

# 'etat': 'VIGUEUR'
# JORF
#structure (ex: livre , chapitre, section ...)
# n°article
#titre': "Décret n° 2021-922 du 13 juillet 2021 portant création, auprès du secrétaire général de la défense et de la sécurité nationale, d'un service à compétence nationale dénommé « service de vigilance et de protection contre les ingérences numériques étrangères »",
# Out:
# {'executionTime': 0,
#  'dereferenced': False,
#  'article': {'id': 'JORFARTI000043788371',
#   'idTexte': None,
#   'type': 'ENTIEREMENT_MODIF',
#   'texte': "Le code de la défense est ainsi modifié : 1° L'article R.* 1132-3 est complété par un 9° ainsi rédigé : « 9° En liaison avec les départements ministériels concernés, il identifie les opérations impliquant, de manière directe ou indirecte, un Etat étranger ou une entité non étatique étrangère, et visant à la diffusion artificielle ou automatisée, massive et délibérée, par le biais d'un service de communication au public en ligne, d'allégations ou imputations de faits manifestement inexactes ou trompeuses de nature à porter atteinte aux intérêts fondamentaux de la Nation. Il anime et coordonne les travaux interministériels en matière de protection contre ces opérations. » ; 2° La section 1 du chapitre II du titre III du livre premier de la première partie est complétée par un article D. 1132-8 ainsi rédigé : « Art. D. 1132-8. - Pour assurer les missions qui lui sont assignées au 9° de l'article R.* 1132-3, le secrétaire général de la défense et de la sécurité nationale dispose du service à compétence nationale dénommé “service de vigilance et de protection contre les ingérences numériques étrangères”. »",
#   'texteHtml': "<p><br/>Le code de la défense est ainsi modifié :<br/>1° L'article R.* 1132-3 est complété par un 9° ainsi rédigé :<br/>« 9° En liaison avec les départements ministériels concernés, il identifie les opérations impliquant, de manière directe ou indirecte, un Etat étranger ou une entité non étatique étrangère, et visant à la diffusion artificielle ou automatisée, massive et délibérée, par le biais d'un service de communication au public en ligne, d'allégations ou imputations de faits manifestement inexactes ou trompeuses de nature à porter atteinte aux intérêts fondamentaux de la Nation. Il anime et coordonne les travaux interministériels en matière de protection contre ces opérations. » ;<br/>2° La section 1 du chapitre II du titre III du livre premier de la première partie est complétée par un article D. 1132-8 ainsi rédigé :</p><p><br/>« Art. D. 1132-8. - Pour assurer les missions qui lui sont assignées au 9° de l'article R.* 1132-3, le secrétaire général de la défense et de la sécurité nationale dispose du service à compétence nationale dénommé “service de vigilance et de protection contre les ingérences numériques étrangères”. »</p>",
#   'num': '1',
#   'origine': 'JORF',
#   'nature': 'Article',
#   'versionArticle': 'INITIALE',
#   'etat': 'INITIALE',
#   'dateDebut': 32472144000000,
#   'dateFin': 32472144000000,
#   'dateDebutExtension': 32472144000000,
#   'dateFinExtension': 32472144000000,
#   'inap': '0',
#   'ordre': 524287,
#   'context': {'titresTM': [{'debut': '2999-01-01',
#      'fin': '2999-01-01',
#      'titre': 'Chapitre Ier : Attributions du secrétaire général de la défense et de la sécurité nationale en matière de lutte contre les ingérences numériques étrangères',
#      'xPath': '/ARTICLE/CONTEXTE/TEXTE/TM/TITRE_TM',
#      'cid': 'JORFSCTA000043788368',
#      'id': 'JORFSCTA000043788368',
#      'etat': ''}],
#    'nombreVersionParent': 1,
#    'longeurChemin': 35,
#    'titreTxt': [{'debut': '2999-01-01',
#      'fin': '2999-01-01',
#      'titre': "Décret n° 2021-922 du 13 juillet 2021 portant création, auprès du secrétaire général de la défense et de la sécurité nationale, d'un service à compétence nationale dénommé « service de vigilance et de protection contre les ingérences numériques étrangères »",
#      'xPath': '/ARTICLE/CONTEXTE/TEXTE/TITRE_TXT',
#      'cid': 'JORFTEXT000043788361',
#      'id': 'JORFTEXT000043788361',
#      'etat': ''},
#     {'debut': '2021-07-15',
#      'fin': '2999-01-01',
#      'titre': "Décret n° 2021-922 du 13 juillet 2021 portant création, auprès du secrétaire général de la défense et de la sécurité nationale, d'un service à compétence nationale dénommé « service de vigilance et de protection contre les ingérences numériques étrangères »",
#      'xPath': '/ARTICLE/CONTEXTE/TEXTE/TITRE_TXT',
#      'cid': 'JORFTEXT000043788361',
#      'id': 'LEGITEXT000043789529',
#      'etat': 'VIGUEUR'}]},
#   'cid': None,
#   'cidTexte': None,
#   'sectionParentCid': 'JORFSCTA000043788368',
#   'sectionParentId': 'JORFSCTA000043788368',
#   'sectionParentTitre': 'Chapitre Ier : Attributions du secrétaire général de la défense et de la sécurité nationale en matière de lutte contre les ingérences numériques étrangères',
#   'fullSectionsTitre': 'Chapitre Ier : Attributions du secrétaire général de la défense et de la sécurité nationale en matière de lutte contre les ingérences numériques étrangères',
#   'refInjection': 'IG-20231125',
#   'idTechInjection': 'JORFARTI000043788371',
#   'idEli': '/eli/decret/2021/7/13/PRMD2117108D/jo/article_1',
#   'idEliAlias': '/eli/decret/2021/7/13/2021-922/jo/article_1',
#   'calipsos': [],
#   'textTitles': [{'id': 'JORFTEXT000043788361',
#     'titre': 'Décret n°2021-922 du 13 juillet 2021',
#     'titreLong': "Décret n° 2021-922 du 13 juillet 2021 portant création, auprès du secrétaire général de la défense et de la sécurité nationale, d'un service à compétence nationale dénommé « service de vigilance et de protection contre les ingérences numériques étrangères »",
#     'etat': '',
#     'dateDebut': 32472144000000,
#     'dateFin': 32472144000000,
#     'cid': 'JORFTEXT000043788361',
#     'datePubli': 1626220800000,
#     'datePubliComputed': 1626220800000,
#     'dateTexte': 1626134400000,
#     'dateTexteComputed': 1626134400000,
#     'nature': 'DECRET',
#     'nor': 'PRMD2117108D',
#     'num': '2021-922',
#     'numParution': '0162',
#     'originePubli': 'JORF n° 0162 du 14 juillet 2021',
#     'appliGeo': None,
#     'codesNomenclatures': [],
#     'visas': None,
#     'nota': None,
#     'notice': None,
#     'travauxPreparatoires': None,
#     'signataires': None,
#     'dossiersLegislatifs': [],
#     'ancienId': None,
#     'appellations': None},
#    {'id': 'LEGITEXT000043789529',
#     'titre': 'Décret n°2021-922 du 13 juillet 2021',
#     'titreLong': "Décret n° 2021-922 du 13 juillet 2021 portant création, auprès du secrétaire général de la défense et de la sécurité nationale, d'un service à compétence nationale dénommé « service de vigilance et de protection contre les ingérences numériques étrangères »",
#     'etat': 'VIGUEUR',
#     'dateDebut': 1626307200000,
#     'dateFin': 32472144000000,
#     'cid': 'JORFTEXT000043788361',
#     'datePubli': 1626220800000,
#     'datePubliComputed': 1626220800000,
#     'dateTexte': 1626134400000,
#     'dateTexteComputed': 1626134400000,
#     'nature': 'DECRET',
#     'nor': 'PRMD2117108D',
#     'num': '2021-922',
#     'numParution': '0162',
#     'originePubli': 'JORF n° 0162 du 14 juillet 2021',
#     'appliGeo': None,
#     'codesNomenclatures': [],
#     'visas': None,
#     'nota': None,
#     'notice': None,
#     'travauxPreparatoires': None,
#     'signataires': None,
#     'dossiersLegislatifs': [],
#     'ancienId': None,
#     'appellations': None}],
#   'nota': None,
#   'notaHtml': None,
#   'activitePro': [],
#   'numeroBrochure': [],
#   'numeroBo': None,
#   'conteneurs': [],
#   'lienModifications': [],
#   'lienCitations': [],
#   'lienConcordes': [],
#   'lienAutres': [],
#   'articleVersions': [{'id': 'LEGIARTI000043789542',
#     'etat': '',
#     'version': '1.0',
#     'dateDebut': 32472144000000,
#     'dateFin': 32472144000000,
#     'numero': None,
#     'ordre': None},
#    {'id': 'JORFARTI000043788371',
#     'etat': '',
#     'version': 'INITIALE',
#     'dateDebut': 32472144000000,
#     'dateFin': 32472144000000,
#     'numero': None,
#     'ordre': None}],
#   'computedNums': ['1'],
#   'versionPrecedente': None,
#   'conditionDiffere': None,
#   'historique': None,
#   'surtitre': None,
#   'renvoi': None,
#   'infosComplementaires': None,
#   'infosComplementairesHtml': None,
#   'infosRestructurationBranche': None,
#   'infosRestructurationBrancheHtml': None,
#   'comporteLiensSP': False,
#   'multipleVersions': False}}

# %%
response_json['article']['textTitles'][1]["titreLong"]
# Out:
# "Décret n° 2021-922 du 13 juillet 2021 portant création, auprès du secrétaire général de la défense et de la sécurité nationale, d'un service à compétence nationale dénommé « service de vigilance et de protection contre les ingérences numériques étrangères »"

# %%
response_json['article']['idEliAlias']
# Out:
# '/eli/decret/2021/7/13/2021-922/jo/article_1'

# %%
response_json['article']['texte']
# Out:
# "Le code de la défense est ainsi modifié : 1° L'article R.* 1132-3 est complété par un 9° ainsi rédigé : « 9° En liaison avec les départements ministériels concernés, il identifie les opérations impliquant, de manière directe ou indirecte, un Etat étranger ou une entité non étatique étrangère, et visant à la diffusion artificielle ou automatisée, massive et délibérée, par le biais d'un service de communication au public en ligne, d'allégations ou imputations de faits manifestement inexactes ou trompeuses de nature à porter atteinte aux intérêts fondamentaux de la Nation. Il anime et coordonne les travaux interministériels en matière de protection contre ces opérations. » ; 2° La section 1 du chapitre II du titre III du livre premier de la première partie est complétée par un article D. 1132-8 ainsi rédigé : « Art. D. 1132-8. - Pour assurer les missions qui lui sont assignées au 9° de l'article R.* 1132-3, le secrétaire général de la défense et de la sécurité nationale dispose du service à compétence nationale dénommé “service de vigilance et de protection contre les ingérences numériques étrangères”. »"

# %% [markdown]
# ## 2.6 - Chrono Controller
#
# 1 - Extrait d'une version d'un texte:
# POST
# /chrono/textCidAndElementCid - ok
#
# 2 - Vérifie si un texte possède des versions:
# GET
# /chrono/textCid/{textCid} - ok
#
# 3 - Version d'un texte:
# POST
# /chrono/textCid - ok
#
# 4 - Test controller:
# GET
# /chrono/ping

# %% [markdown]
# ### 2.6.1  Extrait d'une version d'un texte : chrono/textCidAndElementCid
#
# Récupère un extrait (section ou article) d'une version spécifique d'un texte à partir des identifiants du texte et de l'extrait (section ou article)

# %%
import requests

headers = {
		'accept': 'application/json',
		'Content-Type': 'application/json',
		'Authorization': 'Bearer ' + access_token
	}

url = "https://sandbox-api.piste.gouv.fr/dila/legifrance/lf-engine-app/chrono/textCidAndElementCid"

# elementCid  est un identifiant unique  pour référencer un contenu juridique spécifique,
# exemple  article de loi,  section,  chapitre ou  autre subdivision juridique.

data = {
    "textCid": "LEGITEXT000006072050", # code du travail
    "elementCid": "LEGIARTI000006901817"
}
# Test 1: "textCid": "LEGITEXT000006070721" Code Civil, "elementCid": "LEGIARTI000038033084" -> NA
# Test 2: "textCid": "LEGITEXT000006070721" Code Civil , "elementCid": "LEGIARTI000006417324" -> NA
# Test 3 : "textCid": "LEGITEXT000006072050" Code du Travail + Article L1221-1 "elementCid": "LEGIARTI000006901817" -> ok
# https://www.legifrance.gouv.fr/codes/article_lc/LEGIARTI000006900839

# %%
#  requête GET
response = requests.post(url, headers=headers, json= data)
data = response.json()
display(data)
# Out:
# {'executionTime': 0,
#  'regroupements': [{'title': '2008',
#    'versions': {'2008-05-01': {'dateDebut': 1209600000000,
#      'isEndVersion': False,
#      'articlesModificateurs': {'JORFTEXT000000465978': {'title': 'Ordonnance 2007-329 2007-03-12 JORF 13 mars 2007',
#        'id': 'JORFTEXT000000465978',
#        'nature': 'CODE',
#        'dateDebutCible': 32472144000000,
#        'actions': {'CODIFICATION': {'action': 'CODIFICATION',
#          'parents': {'LEGISCTA000006189538': {'name': 'Section 2 : Information et communication.',
#            'id': 'LEGISCTA000006189538',
#            'cid': 'LEGISCTA000006189538',
#            'cidText': 'LEGITEXT000006072050',
#            'nature': 'CODE',
#            'dateDebut': 1209600000000,
#            'articlesCibles': {'LEGIARTI000006901817': {'name': 'L2262-8',
#              'id': 'LEGIARTI000006901817',
#              'cid': 'LEGIARTI000006901817',
#              'idParent': 'LEGISCTA000006189538',
#              'cidParent': 'LEGISCTA000006189538',
#              'cidText': 'LEGITEXT000006072050',
#              'sens': None,
#              'nature': 'CODE',
#              'path': 'LEGITEXT000006072050/LEGISCTA000006112874/LEGISCTA000006132331/LEGISCTA000006145398/LEGISCTA000006160736/LEGISCTA000006177939/LEGISCTA000006189538/LEGIARTI000006901817',
#              'dateDebut': 1209600000000,
#              'dateFin': 32472144000000}},
#            'sectionsCibles': {},
#            'texteCible': None}}}}}}}},
#    'detailLoaded': True}],
#  'datePublication': '2999-01-01T00:00:00.000+0000'}

# %% [markdown]
# ### 2.6.2  Version d'un texte /chrono/textCid (Binary output)

# %%
import requests

# def text_cid
# LEGITEXT000006073984 # code des assurances : oui
# LEGITEXT000006070721 # code civil : oui
# LEGITEXT000005634379 # Code de commerce : oui
# LEGITEXT000006070719 # code pénal  oui
# LEGITEXT000006072026 # cmf

text_cid = "LEGITEXT000006073984" # input

# URL de l'API + inject textCid
url = f"https://sandbox-api.piste.gouv.fr/dila/legifrance/lf-engine-app/chrono/textCid/{text_cid}"


headers = {
    "accept": "application/json",
    "Authorization": "Bearer " + access_token
}

# Envoi  requête GET
response = requests.get(url, headers=headers)
data = response.json()
display(data)
# Out:
# {'executionTime': 2, 'chronolegiExists': True}

# %%
type(data)
# Out:
# dict

# %%
def version_exist(text_cid):
  url = f"https://sandbox-api.piste.gouv.fr/dila/legifrance/lf-engine-app/chrono/textCid/{text_cid}"
  headers = {
    "accept": "application/json",
        "Authorization": "Bearer " + access_token}
  response = requests.get(url, headers=headers)
  data = response.json()
  return display(data["chronolegiExists"])

# %%
version_exist("LEGITEXT000006073984")
# LEGITEXT000006073984 # code des assurances : oui
# LEGITEXT000006070721 # code civil : oui
# LEGITEXT000005634379 # Code de commerce : oui
# LEGITEXT000006070719 # code pénal  oui
# LEGITEXT000006072026 # cmf
# Out:
# True

# %% [markdown]
# ### 2.6.3 - Récupère une version d'un texte à partir de l'id texte /chrono/textCid

# %%
import requests

headers = {
    'accept': 'application/json',
    'Content-Type': 'application/json',
    'Authorization': 'Bearer ' + access_token
}

# Données de la requête
data = {
  "endYear": 2018,
  "dateConsult": "2021-04-15",
  "startYear": 2015,
  "textCid": "LEGITEXT000006070721"
}

# Envoi de la requête POST
response = requests.post(url, headers=headers, json=data)
display(response)
# Out:
# <Response [200]>

# %%
display(response.json())
# Out:
# {'executionTime': 52,
#  'regroupements': [{'title': '2026',
#    'versions': {'2026-12-31': {'dateDebut': 1798675200000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2026-01-01': {'dateDebut': 1767225600000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}}},
#    'detailLoaded': False},
#   {'title': '2024',
#    'versions': {'2024-09-14': {'dateDebut': 1726272000000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2024-07-05': {'dateDebut': 1720137600000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2024-06-15': {'dateDebut': 1718409600000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2024-06-02': {'dateDebut': 1717286400000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2024-04-17': {'dateDebut': 1713312000000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2024-03-20': {'dateDebut': 1710892800000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2024-02-21': {'dateDebut': 1708473600000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}}},
#    'detailLoaded': False},
#   {'title': '2023',
#    'versions': {'2023-05-21': {'dateDebut': 1684627200000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2023-02-06': {'dateDebut': 1675641600000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2023-01-01': {'dateDebut': 1672531200000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}}},
#    'detailLoaded': False},
#   {'title': '2022',
#    'versions': {'2022-09-01': {'dateDebut': 1661990400000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2022-07-01': {'dateDebut': 1656633600000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2022-03-02': {'dateDebut': 1646179200000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2022-03-01': {'dateDebut': 1646092800000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2022-02-23': {'dateDebut': 1645574400000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2022-02-09': {'dateDebut': 1644364800000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2022-01-26': {'dateDebut': 1643155200000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2022-01-01': {'dateDebut': 1640995200000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}}},
#    'detailLoaded': False},
#   {'title': '2021',
#    'versions': {'2021-12-25': {'dateDebut': 1640390400000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2021-12-24': {'dateDebut': 1640304000000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2021-12-08': {'dateDebut': 1638921600000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2021-11-01': {'dateDebut': 1635724800000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2021-09-17': {'dateDebut': 1631836800000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2021-08-26': {'dateDebut': 1629936000000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2021-08-04': {'dateDebut': 1628035200000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2021-07-01': {'dateDebut': 1625097600000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2021-01-01': {'dateDebut': 1609459200000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}}},
#    'detailLoaded': False},
#   {'title': '2020',
#    'versions': {'2020-12-16': {'dateDebut': 1608076800000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2020-12-09': {'dateDebut': 1607472000000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2020-09-01': {'dateDebut': 1598918400000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2020-08-01': {'dateDebut': 1596240000000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2020-02-14': {'dateDebut': 1581638400000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2020-01-01': {'dateDebut': 1577836800000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}}},
#    'detailLoaded': False},
#   {'title': '2019',
#    'versions': {'2019-12-30': {'dateDebut': 1577664000000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2019-12-28': {'dateDebut': 1577491200000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2019-12-15': {'dateDebut': 1576368000000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2019-10-23': {'dateDebut': 1571788800000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2019-07-21': {'dateDebut': 1563667200000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2019-07-12': {'dateDebut': 1562889600000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2019-05-24': {'dateDebut': 1558656000000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2019-03-25': {'dateDebut': 1553472000000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '2019-03-01': {'dateDebut': 1551398400000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}}},
#    'detailLoaded': False},
#   {'title': '2018',
#    'versions': {'2018-10-01': {'dateDebut': 1538352000000,
#      'isEndVersion': False,
#      'articlesModificateurs': {'LEGIARTI000036828112': {'title': 'LOI n°2018-287 du 20 avril 2018 - art. 6',
#        'id': 'LEGIARTI000036828112',
#        'nature': 'CODE',
#        'dateDebutCible': 1538352000000,
#        'actions': {'MODIFICATION': {'action': 'MODIFICATION',
#          'parents': {'LEGISCTA000032008380': {'name': 'Paragraphe 1 : La capacité \r\n\r\n',
#            'id': 'LEGISCTA000032008380',
#            'cid': 'LEGISCTA000032008380',
#            'cidText': 'LEGITEXT000006070721',
#            'nature': 'CODE',
#            'dateDebut': 1475280000000,
#            'articlesCibles': {'LEGIARTI000036829833': {'name': '1145',
#              'id': 'LEGIARTI000036829833',
#              'cid': 'LEGIARTI000006436355',
#              'idParent': 'LEGISCTA000032008380',
#              'cidParent': 'LEGISCTA000032008380',
#              'cidText': 'LEGITEXT000006070721',
#              'sens': None,
#              'nature': 'CODE',
#              'path': 'LEGITEXT000006070721/LEGISCTA000006090271/LEGISCTA000006118032/LEGISCTA000032006712/LEGISCTA000006136341/LEGISCTA000006150237/LEGISCTA000032008378/LEGISCTA000032008380/LEGIARTI000006436355',
#              'dateDebut': 1538352000000,
#              'dateFin': 32472144000000}},
#            'sectionsCibles': {},
#            'texteCible': None},
#           'LEGISCTA000032008382': {'name': ' Paragraphe 2 : La représentation',
#            'id': 'LEGISCTA000032008382',
#            'cid': 'LEGISCTA000032008382',
#            'cidText': 'LEGITEXT000006070721',
#            'nature': 'CODE',
#            'dateDebut': 1475280000000,
#            'articlesCibles': {'LEGIARTI000036829830': {'name': '1161',
#              'id': 'LEGIARTI000036829830',
#              'cid': 'LEGIARTI000006436486',
#              'idParent': 'LEGISCTA000032008382',
#              'cidParent': 'LEGISCTA000032008382',
#              'cidText': 'LEGITEXT000006070721',
#              'sens': None,
#              'nature': 'CODE',
#              'path': 'LEGITEXT000006070721/LEGISCTA000006090271/LEGISCTA000006118032/LEGISCTA000032006712/LEGISCTA000006136341/LEGISCTA000006150237/LEGISCTA000032008378/LEGISCTA000032008382/LEGIARTI000006436486',
#              'dateDebut': 1538352000000,
#              'dateFin': 32472144000000}},
#            'sectionsCibles': {},
#            'texteCible': None}}}}},
#       'LEGIARTI000036828114': {'title': 'LOI n°2018-287 du 20 avril 2018 - art. 10',
#        'id': 'LEGIARTI000036828114',
#        'nature': 'CODE',
#        'dateDebutCible': 1538352000000,
#        'actions': {'MODIFICATION': {'action': 'MODIFICATION',
#          'parents': {'LEGISCTA000032009923': {'name': "Sous-section 2 : L'exécution forcée en nature ",
#            'id': 'LEGISCTA000032009923',
#            'cid': 'LEGISCTA000032009923',
#            'cidText': 'LEGITEXT000006070721',
#            'nature': 'CODE',
#            'dateDebut': 1475280000000,
#            'articlesCibles': {'LEGIARTI000036829851': {'name': '1221',
#              'id': 'LEGIARTI000036829851',
#              'cid': 'LEGIARTI000006436937',
#              'idParent': 'LEGISCTA000032009923',
#              'cidParent': 'LEGISCTA000032009923',
#              'cidText': 'LEGITEXT000006070721',
#              'sens': None,
#              'nature': 'CODE',
#              'path': 'LEGITEXT000006070721/LEGISCTA000006090271/LEGISCTA000006118032/LEGISCTA000032006712/LEGISCTA000006136343/LEGISCTA000006150254/LEGISCTA000032009923/LEGIARTI000006436937',
#              'dateDebut': 1538352000000,
#              'dateFin': 32472144000000}},
#            'sectionsCibles': {},
#            'texteCible': None},
#           'LEGISCTA000032009925': {'name': 'Sous-section 3 : La réduction du prix ',
#            'id': 'LEGISCTA000032009925',
#            'cid': 'LEGISCTA000032009925',
#            'cidText': 'LEGITEXT000006070721',
#            'nature': 'CODE',
#            'dateDebut': 1475280000000,
#            'articlesCibles': {'LEGIARTI000036829848': {'name': '1223',
#              'id': 'LEGIARTI000036829848',
#              'cid': 'LEGIARTI000006436939',
#              'idParent': 'LEGISCTA000032009925',
#              'cidParent': 'LEGISCTA000032009925',
#              'cidText': 'LEGITEXT000006070721',
#              'sens': None,
#              'nature': 'CODE',
#              'path': 'LEGITEXT000006070721/LEGISCTA000006090271/LEGISCTA000006118032/LEGISCTA000032006712/LEGISCTA000006136343/LEGISCTA000006150254/LEGISCTA000032009925/LEGIARTI000006436939',
#              'dateDebut': 1538352000000,
#              'dateFin': 32472144000000}},
#            'sectionsCibles': {},
#            'texteCible': None},
#           'LEGISCTA000032041441': {'name': "Section 5 : L'inexécution du contrat",
#            'id': 'LEGISCTA000032041441',
#            'cid': 'LEGISCTA000006150254',
#            'cidText': 'LEGITEXT000006070721',
#            'nature': 'CODE',
#            'dateDebut': 1475280000000,
#            'articlesCibles': {'LEGIARTI000036829854': {'name': '1217',
#              'id': 'LEGIARTI000036829854',
#              'cid': 'LEGIARTI000006436894',
#              'idParent': 'LEGISCTA000032041441',
#              'cidParent': 'LEGISCTA000006150254',
#              'cidText': 'LEGITEXT000006070721',
#              'sens': None,
#              'nature': 'CODE',
#              'path': 'LEGITEXT000006070721/LEGISCTA000006090271/LEGISCTA000006118032/LEGISCTA000032006712/LEGISCTA000006136343/LEGISCTA000006150254/LEGIARTI000006436894',
#              'dateDebut': 1538352000000,
#              'dateFin': 32472144000000}},
#            'sectionsCibles': {},
#            'texteCible': None}}}}},
#       'LEGIARTI000036828116': {'title': 'LOI n°2018-287 du 20 avril 2018 - art. 14',
#        'id': 'LEGIARTI000036828116',
#        'nature': 'CODE',
#        'dateDebutCible': 1538352000000,
#        'actions': {'MODIFICATION': {'action': 'MODIFICATION',
#          'parents': {'LEGISCTA000032035257': {'name': "Sous-section 2 : Dispositions particulières aux obligations de sommes d'argent \r\n",
#            'id': 'LEGISCTA000032035257',
#            'cid': 'LEGISCTA000032035257',
#            'cidText': 'LEGITEXT000006070721',
#            'nature': 'CODE',
#            'dateDebut': 1475280000000,
#            'articlesCibles': {'LEGIARTI000036829870': {'name': '1343-3',
#              'id': 'LEGIARTI000036829870',
#              'cid': 'LEGIARTI000032035263',
#              'idParent': 'LEGISCTA000032035257',
#              'cidParent': 'LEGISCTA000032035257',
#              'cidText': 'LEGITEXT000006070721',
#              'sens': None,
#              'nature': 'CODE',
#              'path': 'LEGITEXT000006070721/LEGISCTA000006090271/LEGISCTA000006118073/LEGISCTA000032035231/LEGISCTA000032035233/LEGISCTA000032035257/LEGIARTI000032035263',
#              'dateDebut': 1538352000000,
#              'dateFin': 32472144000000}},
#            'sectionsCibles': {},
#            'texteCible': None}}}}},
#       'LEGIARTI000036828120': {'title': 'LOI n°2018-287 du 20 avril 2018 - art. 2',
#        'id': 'LEGIARTI000036828120',
#        'nature': 'CODE',
#        'dateDebutCible': 1538352000000,
#        'actions': {'MODIFICATION': {'action': 'MODIFICATION',
#          'parents': {'LEGISCTA000032040792': {'name': 'Chapitre Ier : Dispositions liminaires',
#            'id': 'LEGISCTA000032040792',
#            'cid': 'LEGISCTA000006136340',
#            'cidText': 'LEGITEXT000006070721',
#            'nature': 'CODE',
#            'dateDebut': 1475280000000,
#            'articlesCibles': {'LEGIARTI000036829815': {'name': '1110',
#              'id': 'LEGIARTI000036829815',
#              'cid': 'LEGIARTI000006436121',
#              'idParent': 'LEGISCTA000032040792',
#              'cidParent': 'LEGISCTA000006136340',
#              'cidText': 'LEGITEXT000006070721',
#              'sens': None,
#              'nature': 'CODE',
#              'path': 'LEGITEXT000006070721/LEGISCTA000006090271/LEGISCTA000006118032/LEGISCTA000032006712/LEGISCTA000006136340/LEGIARTI000006436121',
#              'dateDebut': 1538352000000,
#              'dateFin': 32472144000000}},
#            'sectionsCibles': {},
#            'texteCible': None}}}}},
#       'LEGIARTI000036828122': {'title': 'LOI n°2018-287 du 20 avril 2018 - art. 3',
#        'id': 'LEGIARTI000036828122',
#        'nature': 'CODE',
#        'dateDebutCible': 1538352000000,
#        'actions': {'MODIFICATION': {'action': 'MODIFICATION',
#          'parents': {'LEGISCTA000032007101': {'name': 'Sous-section 1 : Les négociations',
#            'id': 'LEGISCTA000032007101',
#            'cid': 'LEGISCTA000032007101',
#            'cidText': 'LEGITEXT000006070721',
#            'nature': 'CODE',
#            'dateDebut': 1475280000000,
#            'articlesCibles': {'LEGIARTI000036829818': {'name': '1112',
#              'id': 'LEGIARTI000036829818',
#              'cid': 'LEGIARTI000006436129',
#              'idParent': 'LEGISCTA000032007101',
#              'cidParent': 'LEGISCTA000032007101',
#              'cidText': 'LEGITEXT000006070721',
#              'sens': None,
#              'nature': 'CODE',
#              'path': 'LEGITEXT000006070721/LEGISCTA000006090271/LEGISCTA000006118032/LEGISCTA000032006712/LEGISCTA000006136341/LEGISCTA000006150236/LEGISCTA000032007101/LEGIARTI000006436129',
#              'dateDebut': 1538352000000,
#              'dateFin': 32472144000000}},
#            'sectionsCibles': {},
#            'texteCible': None}}}}},
#       'LEGIARTI000036828124': {'title': 'LOI n°2018-287 du 20 avril 2018 - art. 4',
#        'id': 'LEGIARTI000036828124',
#        'nature': 'CODE',
#        'dateDebutCible': 1538352000000,
#        'actions': {'MODIFICATION': {'action': 'MODIFICATION',
#          'parents': {'LEGISCTA000032007103': {'name': "Sous-section 2 : L'offre et l'acceptation ",
#            'id': 'LEGISCTA000032007103',
#            'cid': 'LEGISCTA000032007103',
#            'cidText': 'LEGITEXT000006070721',
#            'nature': 'CODE',
#            'dateDebut': 1475280000000,
#            'articlesCibles': {'LEGIARTI000036829821': {'name': '1117',
#              'id': 'LEGIARTI000036829821',
#              'cid': 'LEGIARTI000006436150',
#              'idParent': 'LEGISCTA000032007103',
#              'cidParent': 'LEGISCTA000032007103',
#              'cidText': 'LEGITEXT000006070721',
#              'sens': None,
#              'nature': 'CODE',
#              'path': 'LEGITEXT000006070721/LEGISCTA000006090271/LEGISCTA000006118032/LEGISCTA000032006712/LEGISCTA000006136341/LEGISCTA000006150236/LEGISCTA000032007103/LEGIARTI000006436150',
#              'dateDebut': 1538352000000,
#              'dateFin': 32472144000000}},
#            'sectionsCibles': {},
#            'texteCible': None}}}}},
#       'LEGIARTI000036828126': {'title': 'LOI n°2018-287 du 20 avril 2018 - art. 5',
#        'id': 'LEGIARTI000036828126',
#        'nature': 'CODE',
#        'dateDebutCible': 1538352000000,
#        'actions': {'MODIFICATION': {'action': 'MODIFICATION',
#          'parents': {'LEGISCTA000032007571': {'name': 'Paragraphe 2 : Les vices du consentement ',
#            'id': 'LEGISCTA000032007571',
#            'cid': 'LEGISCTA000032007571',
#            'cidText': 'LEGITEXT000006070721',
#            'nature': 'CODE',
#            'dateDebut': 1475280000000,
#            'articlesCibles': {'LEGIARTI000036829824': {'name': '1143',
#              'id': 'LEGIARTI000036829824',
#              'cid': 'LEGIARTI000006436347',
#              'idParent': 'LEGISCTA000032007571',
#              'cidParent': 'LEGISCTA000032007571',
#              'cidText': 'LEGITEXT000006070721',
#              'sens': None,
#              'nature': 'CODE',
#              'path': 'LEGITEXT000006070721/LEGISCTA000006090271/LEGISCTA000006118032/LEGISCTA000032006712/LEGISCTA000006136341/LEGISCTA000006150237/LEGISCTA000032007567/LEGISCTA000032007571/LEGIARTI000006436347',
#              'dateDebut': 1538352000000,
#              'dateFin': 32472144000000},
#             'LEGIARTI000036829827': {'name': '1137',
#              'id': 'LEGIARTI000036829827',
#              'cid': 'LEGIARTI000006436312',
#              'idParent': 'LEGISCTA000032007571',
#              'cidParent': 'LEGISCTA000032007571',
#              'cidText': 'LEGITEXT000006070721',
#              'sens': None,
#              'nature': 'CODE',
#              'path': 'LEGITEXT000006070721/LEGISCTA000006090271/LEGISCTA000006118032/LEGISCTA000032006712/LEGISCTA000006136341/LEGISCTA000006150237/LEGISCTA000032007567/LEGISCTA000032007571/LEGIARTI000006436312',
#              'dateDebut': 1538352000000,
#              'dateFin': 32472144000000}},
#            'sectionsCibles': {},
#            'texteCible': None}}}}},
#       'LEGIARTI000036828128': {'title': 'LOI n°2018-287 du 20 avril 2018 - art. 7',
#        'id': 'LEGIARTI000036828128',
#        'nature': 'CODE',
#        'dateDebutCible': 1538352000000,
#        'actions': {'MODIFICATION': {'action': 'MODIFICATION',
#          'parents': {'LEGISCTA000032008690': {'name': 'Sous-section 3 : Le contenu du contrat ',
#            'id': 'LEGISCTA000032008690',
#            'cid': 'LEGISCTA000032008690',
#            'cidText': 'LEGITEXT000006070721',
#            'nature': 'CODE',
#            'dateDebut': 1475280000000,
#            'articlesCibles': {'LEGIARTI000036829836': {'name': '1171',
#              'id': 'LEGIARTI000036829836',
#              'cid': 'LEGIARTI000006436555',
#              'idParent': 'LEGISCTA000032008690',
#              'cidParent': 'LEGISCTA000032008690',
#              'cidText': 'LEGITEXT000006070721',
#              'sens': None,
#              'nature': 'CODE',
#              'path': 'LEGITEXT000006070721/LEGISCTA000006090271/LEGISCTA000006118032/LEGISCTA000032006712/LEGISCTA000006136341/LEGISCTA000006150237/LEGISCTA000032008690/LEGIARTI000006436555',
#              'dateDebut': 1538352000000,
#              'dateFin': 32472144000000},
#             'LEGIARTI000036829839': {'name': '1165',
#              'id': 'LEGIARTI000036829839',
#              'cid': 'LEGIARTI000006436516',
#              'idParent': 'LEGISCTA000032008690',
#              'cidParent': 'LEGISCTA000032008690',
#              'cidText': 'LEGITEXT000006070721',
#              'sens': None,
#              'nature': 'CODE',
#              'path': 'LEGITEXT000006070721/LEGISCTA000006090271/LEGISCTA000006118032/LEGISCTA000032006712/LEGISCTA000006136341/LEGISCTA000006150237/LEGISCTA000032008690/LEGIARTI000006436516',
#              'dateDebut': 1538352000000,
#              'dateFin': 32472144000000}},
#            'sectionsCibles': {},
#            'texteCible': None}}}}},
#       'LEGIARTI000036828132': {'title': 'LOI n°2018-287 du 20 avril 2018 - art. 9',
#        'id': 'LEGIARTI000036828132',
#        'nature': 'CODE',
#        'dateDebutCible': 1538352000000,
#        'actions': {'MODIFICATION': {'action': 'MODIFICATION',
#          'parents': {'LEGISCTA000032041424': {'name': 'Section 4 : La cession de contrat',
#            'id': 'LEGISCTA000032041424',
#            'cid': 'LEGISCTA000006150253',
#            'cidText': 'LEGITEXT000006070721',
#            'nature': 'CODE',
#            'dateDebut': 1475280000000,
#            'articlesCibles': {'LEGIARTI000036829846': {'name': '1216-3',
#              'id': 'LEGIARTI000036829846',
#              'cid': 'LEGIARTI000032009849',
#              'idParent': 'LEGISCTA000032041424',
#              'cidParent': 'LEGISCTA000006150253',
#              'cidText': 'LEGITEXT000006070721',
#              'sens': None,
#              'nature': 'CODE',
#              'path': 'LEGITEXT000006070721/LEGISCTA000006090271/LEGISCTA000006118032/LEGISCTA000032006712/LEGISCTA000006136343/LEGISCTA000006150253/LEGIARTI000032009849',
#              'dateDebut': 1538352000000,
#              'dateFin': 32472144000000}},
#            'sectionsCibles': {},
#            'texteCible': None}}}}},
#       'LEGIARTI000036828134': {'title': 'LOI n°2018-287 du 20 avril 2018 - art. 11',
#        'id': 'LEGIARTI000036828134',
#        'nature': 'CODE',
#        'dateDebutCible': 1538352000000,
#        'actions': {'MODIFICATION': {'action': 'MODIFICATION',
#          'parents': {'LEGISCTA000032028608': {'name': "Section 1 : L'obligation conditionnelle",
#            'id': 'LEGISCTA000032028608',
#            'cid': 'LEGISCTA000032028608',
#            'cidText': 'LEGITEXT000006070721',
#            'nature': 'CODE',
#            'dateDebut': 1475280000000,
#            'articlesCibles': {'LEGIARTI000036829859': {'name': '1304-4',
#              'id': 'LEGIARTI000036829859',
#              'cid': 'LEGIARTI000032029500',
#              'idParent': 'LEGISCTA000032028608',
#              'cidParent': 'LEGISCTA000032028608',
#              'cidText': 'LEGITEXT000006070721',
#              'sens': None,
#              'nature': 'CODE',
#              'path': 'LEGITEXT000006070721/LEGISCTA000006090271/LEGISCTA000006118073/LEGISCTA000006136351/LEGISCTA000032028608/LEGIARTI000032029500',
#              'dateDebut': 1538352000000,
#              'dateFin': 32472144000000}},
#            'sectionsCibles': {},
#            'texteCible': None},
#           'LEGISCTA000032030675': {'name': "Section 2 : L'obligation à terme ",
#            'id': 'LEGISCTA000032030675',
#            'cid': 'LEGISCTA000032030675',
#            'cidText': 'LEGITEXT000006070721',
#            'nature': 'CODE',
#            'dateDebut': 1475280000000,
#            'articlesCibles': {'LEGIARTI000036858404': {'name': '1305-5',
#              'id': 'LEGIARTI000036858404',
#              'cid': 'LEGIARTI000032030685',
#              'idParent': 'LEGISCTA000032030675',
#              'cidParent': 'LEGISCTA000032030675',
#              'cidText': 'LEGITEXT000006070721',
#              'sens': None,
#              'nature': 'CODE',
#              'path': 'LEGITEXT000006070721/LEGISCTA000006090271/LEGISCTA000006118073/LEGISCTA000006136351/LEGISCTA000032030675/LEGIARTI000032030685',
#              'dateDebut': 1538352000000,
#              'dateFin': 32472144000000}},
#            'sectionsCibles': {},
#            'texteCible': None}}}}},
#       'LEGIARTI000036828136': {'title': 'LOI n°2018-287 du 20 avril 2018 - art. 12',
#        'id': 'LEGIARTI000036828136',
#        'nature': 'CODE',
#        'dateDebutCible': 1538352000000,
#        'actions': {'MODIFICATION': {'action': 'MODIFICATION',
#          'parents': {'LEGISCTA000032034723': {'name': 'Section 2 : La cession de dette \r\n',
#            'id': 'LEGISCTA000032034723',
#            'cid': 'LEGISCTA000032034723',
#            'cidText': 'LEGITEXT000006070721',
#            'nature': 'CODE',
#            'dateDebut': 1475280000000,
#            'articlesCibles': {'LEGIARTI000036829861': {'name': '1327',
#              'id': 'LEGIARTI000036829861',
#              'cid': 'LEGIARTI000006438006',
#              'idParent': 'LEGISCTA000032034723',
#              'cidParent': 'LEGISCTA000032034723',
#              'cidText': 'LEGITEXT000006070721',
#              'sens': None,
#              'nature': 'CODE',
#              'path': 'LEGITEXT000006070721/LEGISCTA000006090271/LEGISCTA000006118073/LEGISCTA000032032398/LEGISCTA000032034723/LEGIARTI000006438006',
#              'dateDebut': 1538352000000,
#              'dateFin': 32472144000000}},
#            'sectionsCibles': {},
#            'texteCible': None}}}}},
#       'LEGIARTI000036828138': {'title': 'LOI n°2018-287 du 20 avril 2018 - art. 13',
#        'id': 'LEGIARTI000036828138',
#        'nature': 'CODE',
#        'dateDebutCible': 1538352000000,
#        'actions': {'MODIFICATION': {'action': 'MODIFICATION',
#          'parents': {'LEGISCTA000032034723': {'name': 'Section 2 : La cession de dette \r\n',
#            'id': 'LEGISCTA000032034723',
#            'cid': 'LEGISCTA000032034723',
#            'cidText': 'LEGITEXT000006070721',
#            'nature': 'CODE',
#            'dateDebut': 1475280000000,
#            'articlesCibles': {'LEGIARTI000036829866': {'name': '1328-1',
#              'id': 'LEGIARTI000036829866',
#              'cid': 'LEGIARTI000032034729',
#              'idParent': 'LEGISCTA000032034723',
#              'cidParent': 'LEGISCTA000032034723',
#              'cidText': 'LEGITEXT000006070721',
#              'sens': None,
#              'nature': 'CODE',
#              'path': 'LEGITEXT000006070721/LEGISCTA000006090271/LEGISCTA000006118073/LEGISCTA000032032398/LEGISCTA000032034723/LEGIARTI000032034729',
#              'dateDebut': 1538352000000,
#              'dateFin': 32472144000000},
#             'LEGIARTI000036829868': {'name': '1327-1',
#              'id': 'LEGIARTI000036829868',
#              'cid': 'LEGIARTI000032034725',
#              'idParent': 'LEGISCTA000032034723',
#              'cidParent': 'LEGISCTA000032034723',
#              'cidText': 'LEGITEXT000006070721',
#              'sens': None,
#              'nature': 'CODE',
#              'path': 'LEGITEXT000006070721/LEGISCTA000006090271/LEGISCTA000006118073/LEGISCTA000032032398/LEGISCTA000032034723/LEGIARTI000032034725',
#              'dateDebut': 1538352000000,
#              'dateFin': 32472144000000}},
#            'sectionsCibles': {},
#            'texteCible': None},
#           'LEGISCTA000032035812': {'name': 'Chapitre V : Les restitutions ',
#            'id': 'LEGISCTA000032035812',
#            'cid': 'LEGISCTA000032035812',
#            'cidText': 'LEGITEXT000006070721',
#            'nature': 'CODE',
#            'dateDebut': 1475280000000,
#            'articlesCibles': {'LEGIARTI000036829864': {'name': '1352-4',
#              'id': 'LEGIARTI000036829864',
#              'cid': 'LEGIARTI000032035820',
#              'idParent': 'LEGISCTA000032035812',
#              'cidParent': 'LEGISCTA000032035812',
#              'cidText': 'LEGITEXT000006070721',
#              'sens': None,
#              'nature': 'CODE',
#              'path': 'LEGITEXT000006070721/LEGISCTA000006090271/LEGISCTA000006118073/LEGISCTA000032035812/LEGIARTI000032035820',
#              'dateDebut': 1538352000000,
#              'dateFin': 32472144000000}},
#            'sectionsCibles': {},
#            'texteCible': None}}}}},
#       'LEGIARTI000036828140': {'title': 'LOI n°2018-287 du 20 avril 2018 - art. 15',
#        'id': 'LEGIARTI000036828140',
#        'nature': 'CODE',
#        'dateDebutCible': 1538352000000,
#        'actions': {'MODIFICATION': {'action': 'MODIFICATION',
#          'parents': {'LEGISCTA000032035645': {'name': 'Sous-section 1 : Règles générales ',
#            'id': 'LEGISCTA000032035645',
#            'cid': 'LEGISCTA000032035645',
#            'cidText': 'LEGITEXT000006070721',
#            'nature': 'CODE',
#            'dateDebut': 1475280000000,
#            'articlesCibles': {'LEGIARTI000036829874': {'name': '1347-6',
#              'id': 'LEGIARTI000036829874',
#              'cid': 'LEGIARTI000032035657',
#              'idParent': 'LEGISCTA000032035645',
#              'cidParent': 'LEGISCTA000032035645',
#              'cidText': 'LEGITEXT000006070721',
#              'sens': None,
#              'nature': 'CODE',
#              'path': 'LEGITEXT000006070721/LEGISCTA000006090271/LEGISCTA000006118073/LEGISCTA000032035231/LEGISCTA000032035643/LEGISCTA000032035645/LEGIARTI000032035657',
#              'dateDebut': 1538352000000,
#              'dateFin': 32472144000000}},
#            'sectionsCibles': {},
#            'texteCible': None}}}}}}},
#     '2018-08-06': {'dateDebut': 1533513600000,
#      'isEndVersion': False,
#      'articlesModificateurs': {'LEGIARTI000037286941': {'title': 'LOI n°2018-703 du 3 août 2018 - art. 18',
#        'id': 'LEGIARTI000037286941',
#        'nature': 'CODE',
#        'dateDebutCible': 1533513600000,
#        'actions': {'MODIFICATION': {'action': 'MODIFICATION',
#          'parents': {'LEGISCTA000006150284': {'name': 'Section 2 : De la rescision de la vente pour cause de lésion.',
#            'id': 'LEGISCTA000006150284',
#            'cid': 'LEGISCTA000006150284',
#            'cidText': 'LEGITEXT000006070721',
#            'nature': 'CODE',
#            'dateDebut': -5231606400000,
#            'articlesCibles': {'LEGIARTI000037289780': {'name': '1676',
#              'id': 'LEGIARTI000037289780',
#              'cid': 'LEGIARTI000006442343',
#              'idParent': 'LEGISCTA000006150284',
#              'cidParent': 'LEGISCTA000006150284',
#              'cidText': 'LEGITEXT000006070721',
#              'sens': None,
#              'nature': 'CODE',
#              'path': 'LEGITEXT000006070721/LEGISCTA000006090271/LEGISCTA000006118107/LEGISCTA000006136383/LEGISCTA000006150284/LEGIARTI000006442343',
#              'dateDebut': 1533513600000,
#              'dateFin': 32472144000000}},
#            'sectionsCibles': {},
#            'texteCible': None}}}}},
#       'UNKNOWN': {'title': 'Un texte d’une portée générale',
#        'id': 'UNKNOWN',
#        'nature': 'CODE',
#        'dateDebutCible': -5231606400000,
#        'actions': {'MODIFICATION': {'action': 'MODIFICATION',
#          'parents': {'LEGISCTA000006150284': {'name': 'Section 2 : De la rescision de la vente pour cause de lésion.',
#            'id': 'LEGISCTA000006150284',
#            'cid': 'LEGISCTA000006150284',
#            'cidText': 'LEGITEXT000006070721',
#            'nature': 'CODE',
#            'dateDebut': -5231606400000,
#            'articlesCibles': {'LEGIARTI000006442343': {'name': '1676',
#              'id': 'LEGIARTI000006442343',
#              'cid': 'LEGIARTI000006442343',
#              'idParent': 'LEGISCTA000006150284',
#              'cidParent': 'LEGISCTA000006150284',
#              'cidText': 'LEGITEXT000006070721',
#              'sens': None,
#              'nature': 'CODE',
#              'path': 'LEGITEXT000006070721/LEGISCTA000006090271/LEGISCTA000006118107/LEGISCTA000006136383/LEGISCTA000006150284/LEGIARTI000006442343',
#              'dateDebut': -5231606400000,
#              'dateFin': 1533513600000}},
#            'sectionsCibles': {},
#            'texteCible': None}}}}}}},
#     '2018-01-03': {'dateDebut': 1514937600000,
#      'isEndVersion': False,
#      'articlesModificateurs': {'LEGIARTI000035014381': {'title': 'Ordonnance n°2017-1107 du 22 juin 2017 - art. 17',
#        'id': 'LEGIARTI000035014381',
#        'nature': 'CODE',
#        'dateDebutCible': 1498608000000,
#        'actions': {'MODIFICATION': {'action': 'MODIFICATION',
#          'parents': {'LEGISCTA000006118476': {'name': 'Titre XIV : De la fiducie',
#            'id': 'LEGISCTA000006118476',
#            'cid': 'LEGISCTA000006118476',
#            'cidText': 'LEGITEXT000006070721',
#            'nature': 'CODE',
#            'dateDebut': 1172016000000,
#            'articlesCibles': {'LEGIARTI000035044009': {'name': '2015',
#              'id': 'LEGIARTI000035044009',
#              'cid': 'LEGIARTI000006445373',
#              'idParent': 'LEGISCTA000006118476',
#              'cidParent': 'LEGISCTA000006118476',
#              'cidText': 'LEGITEXT000006070721',
#              'sens': None,
#              'nature': 'CODE',
#              'path': 'LEGITEXT000006070721/LEGISCTA000006090271/LEGISCTA000006118476/LEGIARTI000006445373',
#              'dateDebut': 1514937600000,
#              'dateFin': 32472144000000}},
#            'sectionsCibles': {},
#            'texteCible': None}}}}}}},
#     '2018-01-01': {'dateDebut': 1514764800000,
#      'isEndVersion': False,
#      'articlesModificateurs': {'LEGIARTI000035881211': {'title': 'Ordonnance n°2017-1491 du 25 octobre 2017 - art. 13 (VD)',
#        'id': 'LEGIARTI000035881211',
#        'nature': 'CODE',
#        'dateDebutCible': 1514764800000,
#        'actions': {'MODIFICATION': {'action': 'MODIFICATION',
#          'parents': {'LEGISCTA000006118237': {'name': 'Titre III : Dispositions relatives au livre III',
#            'id': 'LEGISCTA000006118237',
#            'cid': 'LEGISCTA000006118237',
#            'cidText': 'LEGITEXT000006070721',
#            'nature': 'CODE',
#            'dateDebut': 1143158400000,
#            'articlesCibles': {'LEGIARTI000035902940': {'name': '2508',
#              'id': 'LEGIARTI000035902940',
#              'cid': 'LEGIARTI000006450720',
#              'idParent': 'LEGISCTA000006118237',
#              'cidParent': 'LEGISCTA000006118237',
#              'cidText': 'LEGITEXT000006070721',
#              'sens': None,
#              'nature': 'CODE',
#              'path': 'LEGITEXT000006070721/LEGISCTA000006091523/LEGISCTA000006118237/LEGIARTI000006450720',
#              'dateDebut': 1514764800000,
#              'dateFin': 32472144000000}},
#            'sectionsCibles': {},
#            'texteCible': None}}}}}}}},
#    'detailLoaded': True},
#   {'title': '2017',
#    'versions': {'2017-11-01': {'dateDebut': 1509494400000,
#      'isEndVersion': False,
#      'articlesModificateurs': {'LEGIARTI000033423832': {'title': 'LOI n°2016-1547 du 18 novembre 2016 - art. 44',
#        'id': 'LEGIARTI000033423832',
#        'nature': 'CODE',
#        'dateDebutCible': 1479600000000,
#        'actions': {'ABROGATION': {'action': 'ABROGATION',
#          'parents': {'LEGISCTA000006150549': {'name': 'Section 4 : Du legs universel.',
#            'id': 'LEGISCTA000006150549',
#            'cid': 'LEGISCTA000006150549',
#            'cidText': 'LEGITEXT000006070721',
#            'nature': 'CODE',
#            'dateDebut': 1167609600000,
#            'articlesCibles': {'LEGIARTI000006434619': {'name': '1008',
#              'id': 'LEGIARTI000006434619',
#              'cid': 'LEGIARTI000006434618',
#              'idParent': 'LEGISCTA000006150549',
#              'cidParent': 'LEGISCTA000006150549',
#              'cidText': 'LEGITEXT000006070721',
#              'sens': None,
#              'nature': 'CODE',
#              'path': 'LEGITEXT000006070721/LEGISCTA000006090271/LEGISCTA000006118022/LEGISCTA000006136338/LEGISCTA000006150549/LEGIARTI000006434618',
#              'dateDebut': 1167609600000,
#              'dateFin': 1509494400000}},
#            'sectionsCibles': {},
#            'texteCible': None}}},
#         'MODIFICATION': {'action': 'MODIFICATION',
#          'parents': {'LEGISCTA000006150233': {'name': 'Section 7 : Des exécuteurs testamentaires.',
#            'id': 'LEGISCTA000006150233',
#            'cid': 'LEGISCTA000006150233',
#            'cidText': 'LEGITEXT000006070721',
#            'nature': 'CODE',
#            'dateDebut': 1167609600000,
#            'articlesCibles': {'LEGIARTI000033460699': {'name': '1030-2',
#              'id': 'LEGIARTI000033460699',
#              'cid': 'LEGIARTI000006436026',
#              'idParent': 'LEGISCTA000006150233',
#              'cidParent': 'LEGISCTA000006150233',
#              'cidText': 'LEGITEXT000006070721',
#              'sens': None,
#              'nature': 'CODE',
#              'path': 'LEGITEXT000006070721/LEGISCTA000006090271/LEGISCTA000006118022/LEGISCTA000006136338/LEGISCTA000006150233/LEGIARTI000006436026',
#              'dateDebut': 1509494400000,
#              'dateFin': 32472144000000}},
#            'sectionsCibles': {},
#            'texteCible': None},
#           'LEGISCTA000006150549': {'name': 'Section 4 : Du legs universel.',
#            'id': 'LEGISCTA000006150549',
#            'cid': 'LEGISCTA000006150549',
#            'cidText': 'LEGITEXT000006070721',
#            'nature': 'CODE',
#            'dateDebut': 1167609600000,
#            'articlesCibles': {'LEGIARTI000033460709': {'name': '1007',
#              'id': 'LEGIARTI000033460709',
#              'cid': 'LEGIARTI000006434607',
#              'idParent': 'LEGISCTA000006150549',
#              'cidParent': 'LEGISCTA000006150549',
#              'cidText': 'LEGITEXT000006070721',
#              'sens': None,
#              'nature': 'CODE',
#              'path': 'LEGITEXT000006070721/LEGISCTA000006090271/LEGISCTA000006118022/LEGISCTA000006136338/LEGISCTA000006150549/LEGIARTI000006434607',
#              'dateDebut': 1509494400000,
#              'dateFin': 1577836800000}},
#            'sectionsCibles': {},
#            'texteCible': None}}}}},
#       'LEGIARTI000033423834': {'title': 'LOI n°2016-1547 du 18 novembre 2016 - art. 45',
#        'id': 'LEGIARTI000033423834',
#        'nature': 'CODE',
#        'dateDebutCible': 1479600000000,
#        'actions': {'MODIFICATION': {'action': 'MODIFICATION',
#          'parents': {'LEGISCTA000006150536': {'name': 'Section 4 : De la renonciation à la succession.',
#            'id': 'LEGISCTA000006150536',
#            'cid': 'LEGISCTA000006150536',
#            'cidText': 'LEGITEXT000006070721',
#            'nature': 'CODE',
#            'dateDebut': 1167609600000,
#            'articlesCibles': {'LEGIARTI000033460712': {'name': '804',
#              'id': 'LEGIARTI000033460712',
#              'cid': 'LEGIARTI000006431738',
#              'idParent': 'LEGISCTA000006150536',
#              'cidParent': 'LEGISCTA000006150536',
#              'cidText': 'LEGITEXT000006070721',
#              'sens': None,
#              'nature': 'CODE',
#              'path': 'LEGITEXT000006070721/LEGISCTA000006090271/LEGISCTA000006117929/LEGISCTA000006136273/LEGISCTA000006150536/LEGIARTI000006431738',
#              'dateDebut': 1509494400000,
#              'dateFin': 32472144000000}},
#            'sectionsCibles': {},
#            'texteCible': None}}}}},
#       'LEGIARTI000033423840': {'title': 'LOI n°2016-1547 du 18 novembre 2016 - art. 46',
#        'id': 'LEGIARTI000033423840',
#        'nature': 'CODE',
#        'dateDebutCible': 1479600000000,
#        'actions': {'MODIFICATION': {'action': 'MODIFICATION',
#          'parents': {'LEGISCTA000006165766': {'name': "Paragraphe 1 : Des modalités de l'acceptation de la succession à concurrence de l'actif net.",
#            'id': 'LEGISCTA000006165766',
#            'cid': 'LEGISCTA000006165766',
#            'cidText': 'LEGITEXT000006070721',
#            'nature': 'CODE',
#            'dateDebut': 1167609600000,
#            'articlesCibles': {'LEGIARTI000033460714': {'name': '788',
#              'id': 'LEGIARTI000033460714',
#              'cid': 'LEGIARTI000006431568',
#              'idParent': 'LEGISCTA000006165766',
#              'cidParent': 'LEGISCTA000006165766',
#              'cidText': 'LEGITEXT000006070721',
#              'sens': None,
#              'nature': 'CODE',
#              'path': 'LEGITEXT000006070721/LEGISCTA000006090271/LEGISCTA000006117929/LEGISCTA000006136273/LEGISCTA000006150144/LEGISCTA000006165766/LEGIARTI000006431568',
#              'dateDebut': 1509494400000,
#              'dateFin': 1577836800000}},
#            'sectionsCibles': {},
#            'texteCible': None}}}}},
#       'LEGIARTI000033423844': {'title': 'LOI n°2016-1547 du 18 novembre 2016 - art. 48 (V)',
#        'id': 'LEGIARTI000033423844',
#        'nature': 'CODE',
#        'dateDebutCible': 1479600000000,
#        'actions': {'ABROGATION': {'action': 'ABROGATION',
#          'parents': {'LEGISCTA000006118228': {'name': 'Titre Ier : Dispositions relatives au livre Ier',
#            'id': 'LEGISCTA000006118228',
#            'cid': 'LEGISCTA000006118228',
#            'cidText': 'LEGITEXT000006070721',
#            'nature': 'CODE',
#            'dateDebut': 1143158400000,
#            'articlesCibles': {'LEGIARTI000021330219': {'name': '2499',
#              'id': 'LEGIARTI000021330219',
#              'cid': 'LEGIARTI000006450491',
#              'idParent': 'LEGISCTA000006118228',
#              'cidParent': 'LEGISCTA000006118228',
#              'cidText': 'LEGITEXT000006070721',
#              'sens': None,
#              'nature': 'CODE',
#              'path': 'LEGITEXT000006070721/LEGISCTA000006091523/LEGISCTA000006118228/LEGIARTI000006450491',
#              'dateDebut': 1259193600000,
#              'dateFin': 1509494400000}},
#            'sectionsCibles': {},
#            'texteCible': None}}},
#         'MODIFICATION': {'action': 'MODIFICATION',
#          'parents': {'LEGISCTA000006136536': {'name': 'Chapitre Ier : Du pacte civil de solidarité',
#            'id': 'LEGISCTA000006136536',
#            'cid': 'LEGISCTA000006136536',
#            'cidText': 'LEGITEXT000006070721',
#            'nature': 'CODE',
#            'dateDebut': 1230768000000,
#            'articlesCibles': {'LEGIARTI000033460726': {'name': '515-7',
#              'id': 'LEGIARTI000033460726',
#              'cid': 'LEGIARTI000006428554',
#              'idParent': 'LEGISCTA000006136536',
#              'cidParent': 'LEGISCTA000006136536',
#              'cidText': 'LEGITEXT000006070721',
#              'sens': None,
#              'nature': 'CODE',
#              'path': 'LEGITEXT000006070721/LEGISCTA000006089697/LEGISCTA000006118360/LEGISCTA000006136536/LEGIARTI000006428554',
#              'dateDebut': 1509494400000,
#              'dateFin': 32472144000000},
#             'LEGIARTI000033460732': {'name': '515-3',
#              'id': 'LEGIARTI000033460732',
#              'cid': 'LEGIARTI000006428481',
#              'idParent': 'LEGISCTA000006136536',
#              'cidParent': 'LEGISCTA000006136536',
#              'cidText': 'LEGITEXT000006070721',
#              'sens': None,
#              'nature': 'CODE',
#              'path': 'LEGITEXT000006070721/LEGISCTA000006089697/LEGISCTA000006118360/LEGISCTA000006136536/LEGIARTI000006428481',
#              'dateDebut': 1509494400000,
#              'dateFin': 32472144000000},
#             'LEGIARTI000033551984': {'name': '515-3-1',
#              'id': 'LEGIARTI000033551984',
#              'cid': 'LEGIARTI000006428492',
#              'idParent': 'LEGISCTA000006136536',
#              'cidParent': 'LEGISCTA000006136536',
#              'cidText': 'LEGITEXT000006070721',
#              'sens': None,
#              'nature': 'CODE',
#              'path': 'LEGITEXT000006070721/LEGISCTA000006089697/LEGISCTA000006118360/LEGISCTA000006136536/LEGIARTI000006428492',
#              'dateDebut': 1509494400000,
#              'dateFin': 32472144000000}},
#            'sectionsCibles': {},
#            'texteCible': None},
#           'LEGISCTA000006165510': {'name': 'Sous-section 4 : Des effets de la curatelle et de la tutelle quant à la protection de la personne',
#            'id': 'LEGISCTA000006165510',
#            'cid': 'LEGISCTA000006165510',
#            'cidText': 'LEGITEXT000006070721',
#            'nature': 'CODE',
#            'dateDebut': 1230768000000,
#            'articlesCibles': {'LEGIARTI000033460734': {'name': '462',
#              'id': 'LEGIARTI000033460734',
#              'cid': 'LEGIARTI000006427760',
#              'idParent': 'LEGISCTA000006165510',
#              'cidParent': 'LEGISCTA000006165510',
#              'cidText': 'LEGITEXT000006070721',
#              'sens': None,
#              'nature': 'CODE',
#              'path': 'LEGITEXT000006070721/LEGISCTA000006089697/LEGISCTA000006117881/LEGISCTA000006136231/LEGISCTA000006150111/LEGISCTA000006165510/LEGIARTI000006427760',
#              'dateDebut': 1509494400000,
#              'dateFin': 1553472000000},
#             'LEGIARTI000033460739': {'name': '461',
#              'id': 'LEGIARTI000033460739',
#              'cid': 'LEGIARTI000006427757',
#              'idParent': 'LEGISCTA000006165510',
#              'cidParent': 'LEGISCTA000006165510',
#              'cidText': 'LEGITEXT000006070721',
#              'sens': None,
#              'nature': 'CODE',
#              'path': 'LEGITEXT000006070721/LEGISCTA000006089697/LEGISCTA000006117881/LEGISCTA000006136231/LEGISCTA000006150111/LEGISCTA000006165510/LEGIARTI000006427757',
#              'dateDebut': 1509494400000,
#              'dateFin': 32472144000000}},
#            'sectionsCibles': {},
#            'texteCible': None}}}}}}},
#     '2017-10-01': {'dateDebut': 1506816000000,
#      'isEndVersion': False,
#      'articlesModificateurs': {'LEGIARTI000020606628': {'title': 'LOI n°2009-526\n du 12 mai 2009 - art. 138 (V)',
#        'id': 'LEGIARTI000020606628',
#        'nature': 'CODE',
#        'dateDebutCible': 1242259200000,
#        'actions': {'ABROGATION': {'action': 'ABROGATION',
#          'parents': {'LEGISCTA000020192995': {'name': 'Chapitre VIII : De la propriété cédée à titre de garantie \r\n\r\n\r\n\r\n\r\n',
#            'id': 'LEGISCTA000020192995',
#            'cid': 'LEGISCTA000020188712',
#            'cidText': 'LEGITEXT000006070721',
#            'nature': 'CODE',
#            'dateDebut': 1233446400000,
#            'articlesCibles': {'LEGIARTI000020192978': {'name': '2488-6',
#              'id': 'LEGIARTI000020192978',
#              'cid': 'LEGIARTI000020188724',
#              'idParent': 'LEGISCTA000020192995',
#              'cidParent': 'LEGISCTA000020188712',
#              'cidText': 'LEGITEXT000006070721',
#              'sens': None,
#              'nature': 'CODE',
#              'path': 'LEGITEXT000006070721/LEGISCTA000006091495/LEGISCTA000006118201/LEGISCTA000006136444/LEGISCTA000020188712/LEGIARTI000020188724',
#              'dateDebut': 1233446400000,
#              'dateFin': 1506816000000}},
#            'sectionsCibles': {},
#            'texteCible': None}}}}},
#       'LEGIARTI000034582560': {'title': 'Ordonnance n°2017-748 du 4 mai 2017 - art. 1',
#        'id': 'LEGIARTI000034582560',
#        'nature': 'CODE',
#        'dateDebutCible': 1506816000000,
#        'actions': {'CREATION': {'action': 'CREATION',
#          'parents': {'LEGISCTA000006091495': {'name': 'Livre IV : Des sûretés',
#            'id': 'LEGISCTA000006091495',
#            'cid': 'LEGISCTA000006091495',
#            'cidText': 'LEGITEXT000006070721',
#            'nature': 'CODE',
#            'dateDebut': 1143158400000,
#            'articlesCibles': {},
#            'sectionsCibles': {'LEGISCTA000034588765': {'name': "Titre III : De l'agent des sûretés",
#              'id': 'LEGISCTA000034588765',
#              'cid': 'LEGISCTA000034583258',
#              'idParent': 'LEGISCTA000006091495',
#              'cidParent': 'LEGISCTA000006091495',
#              'cidText': 'LEGITEXT000006070721',
#              'sens': None,
#              'nature': 'CODE',
#              'path': 'LEGITEXT000006070721/LEGISCTA000006091495/LEGISCTA000034583258',
#              'dateDebut': 1506816000000,
#              'dateFin': 32472144000000}},
#            'texteCible': None},
#           'LEGISCTA000034588765': {'name': "Titre III : De l'agent des sûretés",
#            'id': 'LEGISCTA000034588765',
#            'cid': 'LEGISCTA000034583258',
#            'cidText': 'LEGITEXT000006070721',
#            'nature': 'CODE',
#            'dateDebut': 1506816000000,
#            'articlesCibles': {'LEGIARTI000034588767': {'name': '2488-12',
#              'id': 'LEGIARTI000034588767',
#              'cid': 'LEGIARTI000034583588',
#              'idParent': 'LEGISCTA000034588765',
#              'cidParent': 'LEGISCTA000034583258',
#              'cidText': 'LEGITEXT000006070721',
#              'sens': None,
#              'nature': 'CODE',
#              'path': 'LEGITEXT000006070721/LEGISCTA000006091495/LEGISCTA000034583258/LEGIARTI000034583588',
#              'dateDebut': 1506816000000,
#              'dateFin': 32472144000000},
#             'LEGIARTI000034588769': {'name': '2488-11',
#              'id': 'LEGIARTI000034588769',
#              'cid': 'LEGIARTI000034583586',
#              'idParent': 'LEGISCTA000034588765',
#              'cidParent': 'LEGISCTA000034583258',
#              'cidText': 'LEGITEXT000006070721',
#              'sens': None,
#              'nature': 'CODE',
#              'path': 'LEGITEXT000006070721/LEGISCTA000006091495/LEGISCTA000034583258/LEGIARTI000034583586',
#              'dateDebut': 1506816000000,
#              'dateFin': 1558656000000},
#             'LEGIARTI000034588771': {'name': '2488-10',
#              'id': 'LEGIARTI000034588771',
#              'cid': 'LEGIARTI000034583584',
# ...
#    'detailLoaded': False},
#   {'title': '1966',
#    'versions': {'1966-12-29': {'dateDebut': -94953600000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '1966-11-01': {'dateDebut': -99964800000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '1966-07-14': {'dateDebut': -109468800000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '1966-06-10': {'dateDebut': -112406400000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '1966-02-01': {'dateDebut': -123552000000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '1966-01-01': {'dateDebut': -126230400000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}}},
#    'detailLoaded': False},
#   {'title': '1965',
#    'versions': {'1965-07-14': {'dateDebut': -141004800000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '1965-06-15': {'dateDebut': -143510400000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '1965-06-05': {'dateDebut': -144374400000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '1965-02-01': {'dateDebut': -155088000000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}}},
#    'detailLoaded': False},
#   {'title': '1964',
#    'versions': {'1964-12-15': {'dateDebut': -159235200000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '1964-06-15': {'dateDebut': -175046400000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '1964-05-17': {'dateDebut': -177552000000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}}},
#    'detailLoaded': False},
#   {'title': '1963',
#    'versions': {'1963-11-07': {'dateDebut': -194140800000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '1963-03-02': {'dateDebut': -215740800000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}}},
#    'detailLoaded': False},
#   {'title': '1962',
#    'versions': {'1962-08-09': {'dateDebut': -233452800000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '1962-08-07': {'dateDebut': -233625600000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}}},
#    'detailLoaded': False},
#   {'title': '1961',
#    'versions': {'1961-12-20': {'dateDebut': -253497600000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}}},
#    'detailLoaded': False},
#   {'title': '1960',
#    'versions': {'1960-12-22': {'dateDebut': -284860800000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '1960-05-18': {'dateDebut': -303696000000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '1960-03-31': {'dateDebut': -307843200000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '1960-01-12': {'dateDebut': -314668800000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}}},
#    'detailLoaded': False},
#   {'title': '1959',
#    'versions': {'1959-01-08': {'dateDebut': -346550400000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}}},
#    'detailLoaded': False},
#   {'title': '1958',
#    'versions': {'1958-12-25': {'dateDebut': -347760000000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '1958-12-24': {'dateDebut': -347846400000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '1958-10-28': {'dateDebut': -352771200000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '1958-10-09': {'dateDebut': -354412800000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '1958-08-30': {'dateDebut': -357868800000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '1958-04-30': {'dateDebut': -368409600000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '1958-03-26': {'dateDebut': -371433600000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}}},
#    'detailLoaded': False},
#   {'title': '1957',
#    'versions': {'1957-11-29': {'dateDebut': -381542400000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '1957-11-20': {'dateDebut': -382320000000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '1957-04-18': {'dateDebut': -400982400000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '1957-03-27': {'dateDebut': -402883200000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}}},
#    'detailLoaded': False},
#   {'title': '1956',
#    'versions': {'1956-08-07': {'dateDebut': -422928000000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}}},
#    'detailLoaded': False},
#   {'title': '1955',
#    'versions': {'1955-01-07': {'dateDebut': -472867200000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}}},
#    'detailLoaded': False},
#   {'title': '1950',
#    'versions': {'1950-12-09': {'dateDebut': -601603200000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}}},
#    'detailLoaded': False},
#   {'title': '1949',
#    'versions': {'1949-11-30': {'dateDebut': -633916800000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '1949-04-21': {'dateDebut': -653184000000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}}},
#    'detailLoaded': False},
#   {'title': '1948',
#    'versions': {'1948-08-26': {'dateDebut': -673747200000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '1948-02-22': {'dateDebut': -689817600000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}}},
#    'detailLoaded': False},
#   {'title': '1946',
#    'versions': {'1946-10-07': {'dateDebut': -733276800000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '1946-04-14': {'dateDebut': -748483200000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}}},
#    'detailLoaded': False},
#   {'title': '1945',
#    'versions': {'1945-11-02': {'dateDebut': -762566400000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '1945-10-18': {'dateDebut': -763862400000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '1945-03-29': {'dateDebut': -781401600000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}}},
#    'detailLoaded': False},
#   {'title': '1942',
#    'versions': {'1942-11-04': {'dateDebut': -857088000000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '1942-09-22': {'dateDebut': -860803200000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}}},
#    'detailLoaded': False},
#   {'title': '1941',
#    'versions': {'1941-10-09': {'dateDebut': -890870400000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '1941-10-03': {'dateDebut': -891388800000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '1941-06-15': {'dateDebut': -900892800000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}}},
#    'detailLoaded': False},
#   {'title': '1939',
#    'versions': {'1939-07-30': {'dateDebut': -960163200000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '1939-06-19': {'dateDebut': -963705600000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}}},
#    'detailLoaded': False},
#   {'title': '1938',
#    'versions': {'1938-11-12': {'dateDebut': -982627200000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '1938-06-30': {'dateDebut': -994291200000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '1938-02-20': {'dateDebut': -1005523200000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '1938-02-19': {'dateDebut': -1005609600000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '1938-02-18': {'dateDebut': -1005696000000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}}},
#    'detailLoaded': False},
#   {'title': '1937',
#    'versions': {'1937-04-06': {'dateDebut': -1033171200000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}}},
#    'detailLoaded': False},
#   {'title': '1936',
#    'versions': {'1936-08-22': {'dateDebut': -1052784000000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}}},
#    'detailLoaded': False},
#   {'title': '1934',
#    'versions': {'1934-02-04': {'dateDebut': -1133136000000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}}},
#    'detailLoaded': False},
#   {'title': '1933',
#    'versions': {'1933-03-15': {'dateDebut': -1161302400000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '1933-02-20': {'dateDebut': -1163289600000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '1933-02-02': {'dateDebut': -1164844800000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}}},
#    'detailLoaded': False},
#   {'title': '1932',
#    'versions': {'1932-03-10': {'dateDebut': -1193270400000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}}},
#    'detailLoaded': False},
#   {'title': '1930',
#    'versions': {'1930-12-13': {'dateDebut': -1232409600000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '1930-12-03': {'dateDebut': -1233273600000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '1930-07-30': {'dateDebut': -1244160000000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}}},
#    'detailLoaded': False},
#   {'title': '1929',
#    'versions': {'1929-07-11': {'dateDebut': -1277337600000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}}},
#    'detailLoaded': False},
#   {'title': '1927',
#    'versions': {'1927-08-15': {'dateDebut': -1337472000000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '1927-08-14': {'dateDebut': -1337558400000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '1927-08-10': {'dateDebut': -1337904000000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '1927-07-17': {'dateDebut': -1339977600000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '1927-04-08': {'dateDebut': -1348617600000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}}},
#    'detailLoaded': False},
#   {'title': '1924',
#    'versions': {'1924-02-07': {'dateDebut': -1448496000000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}}},
#    'detailLoaded': False},
#   {'title': '1922',
#    'versions': {'1922-11-09': {'dateDebut': -1487808000000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '1922-10-28': {'dateDebut': -1488844800000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '1922-02-28': {'dateDebut': -1509753600000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}}},
#    'detailLoaded': False},
#   {'title': '1921',
#    'versions': {'1921-02-15': {'dateDebut': -1542412800000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}}},
#    'detailLoaded': False},
#   {'title': '1919',
#    'versions': {'1919-10-27': {'dateDebut': -1583625600000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '1919-08-09': {'dateDebut': -1590451200000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}}},
#    'detailLoaded': False},
#   {'title': '1918',
#    'versions': {'1918-03-01': {'dateDebut': -1635897600000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}}},
#    'detailLoaded': False},
#   {'title': '1915',
#    'versions': {'1915-07-28': {'dateDebut': -1717718400000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}}},
#    'detailLoaded': False},
#   {'title': '1910',
#    'versions': {'1910-12-31': {'dateDebut': -1862006400000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}}},
#    'detailLoaded': False},
#   {'title': '1909',
#    'versions': {'1909-03-17': {'dateDebut': -1918512000000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}}},
#    'detailLoaded': False},
#   {'title': '1907',
#    'versions': {'1907-06-21': {'dateDebut': -1973376000000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '1907-01-21': {'dateDebut': -1986422400000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}}},
#    'detailLoaded': False},
#   {'title': '1900',
#    'versions': {'1900-05-17': {'dateDebut': -2197238400000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '1900-04-10': {'dateDebut': -2200435200000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}}},
#    'detailLoaded': False},
#   {'title': '1898',
#    'versions': {'1898-04-08': {'dateDebut': -2263680000000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '1898-03-24': {'dateDebut': -2264976000000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}}},
#    'detailLoaded': False},
#   {'title': '1896',
#    'versions': {'1896-06-20': {'dateDebut': -2320444800000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '1896-03-25': {'dateDebut': -2327961600000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}}},
#    'detailLoaded': False},
#   {'title': '1893',
#    'versions': {'1893-08-29': {'dateDebut': -2409091200000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '1893-06-08': {'dateDebut': -2416176000000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}}},
#    'detailLoaded': False},
#   {'title': '1892',
#    'versions': {'1892-07-11': {'dateDebut': -2444860800000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}}},
#    'detailLoaded': False},
#   {'title': '1890',
#    'versions': {'1890-12-28': {'dateDebut': -2493331200000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}}},
#    'detailLoaded': False},
#   {'title': '1889',
#    'versions': {'1889-06-28': {'dateDebut': -2540678400000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}}},
#    'detailLoaded': False},
#   {'title': '1883',
#    'versions': {'1883-01-05': {'dateDebut': -2745100800000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}}},
#    'detailLoaded': False},
#   {'title': '1881',
#    'versions': {'1881-08-26': {'dateDebut': -2788041600000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}}},
#    'detailLoaded': False},
#   {'title': '1868',
#    'versions': {'1868-08-02': {'dateDebut': -3200342400000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}}},
#    'detailLoaded': False},
#   {'title': '1854',
#    'versions': {'1854-05-31': {'dateDebut': -3647635200000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}}},
#    'detailLoaded': False},
#   {'title': '1849',
#    'versions': {'1849-05-11': {'dateDebut': -3807129600000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}}},
#    'detailLoaded': False},
#   {'title': '1819',
#    'versions': {'1819-07-14': {'dateDebut': -4748371200000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}}},
#    'detailLoaded': False},
#   {'title': '1804',
#    'versions': {'1804-03-25': {'dateDebut': -5231260800000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '1804-03-21': {'dateDebut': -5231606400000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '1804-03-17': {'dateDebut': -5231952000000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '1804-03-16': {'dateDebut': -5232038400000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '1804-02-17': {'dateDebut': -5234457600000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '1804-02-10': {'dateDebut': -5235062400000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '1804-02-04': {'dateDebut': -5235580800000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}}},
#    'detailLoaded': False},
#   {'title': '1803',
#    'versions': {'1803-08-03': {'dateDebut': -5251564800000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '1803-05-13': {'dateDebut': -5258649600000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '1803-04-29': {'dateDebut': -5259859200000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}},
#     '1803-03-27': {'dateDebut': -5262710400000,
#      'isEndVersion': False,
#      'articlesModificateurs': {}}},
#    'detailLoaded': False}],
#  'datePublication': '2999-01-01T00:00:00.000+0000'}
